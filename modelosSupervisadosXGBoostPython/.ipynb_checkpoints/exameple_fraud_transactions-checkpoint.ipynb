# %%
import xgbClassification as classi
import xgbMulticlassClassification as mclassi
import xgbRegression as reg
import xgbVisualisation as viz
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib as plt
import shap
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
df = pd.read_csv('./../ejerciciosModelosSupervisados/deteccion_transacciones_fraudulentas/datos/data_fraude.csv')

# %%
# pre-process datos (si es necesario)
df = df.rename(columns={'0.1':'Class'}).drop('Unnamed: 0',axis=1)

# %%
yvar = df.Class
xvars = df[[x for x in df.columns if x != 'Class']]

# %%
# dividir train / test para variables independientes (x)  y dependiente (y)
xtrain, xtest, ytrain, ytest = train_test_split(xvars, yvar, train_size = 0.80, random_state = 2)

# %%
trainXGB = classi.makeXGBMatrix(data=xtrain,
                                label=ytrain)

testXGB = classi.makeXGBMatrix(xtest,
                               ytest)

# %%
finalXGB = classi.findXGBClassification(trainXGB,
                                        testXGB,
                                        xtrain,
                                        ytrain,
                                        xtest,
                                        ytest,
                                        iters=10)
# Out:
# [0]	train-auc:0.95237+0.00359	test-auc:0.94703+0.01464
# [1]	train-auc:0.96177+0.00851	test-auc:0.95476+0.01577
# [2]	train-auc:0.96931+0.00691	test-auc:0.96160+0.01677
# [3]	train-auc:0.97341+0.00560	test-auc:0.96616+0.01780
# [4]	train-auc:0.97605+0.00563	test-auc:0.96993+0.01875
# [5]	train-auc:0.97734+0.00429	test-auc:0.97173+0.01428
# [6]	train-auc:0.97824+0.00505	test-auc:0.97186+0.01482
# [7]	train-auc:0.97926+0.00469	test-auc:0.97309+0.01400
# [8]	train-auc:0.98078+0.00412	test-auc:0.97491+0.01487
# [9]	train-auc:0.98126+0.00422	test-auc:0.97530+0.01425
# [0]	train-auc:0.96972+0.00374	test-auc:0.96531+0.01331
# [1]	train-auc:0.97797+0.00598	test-auc:0.97163+0.00838
# [2]	train-auc:0.98427+0.00403	test-auc:0.98103+0.00808
# [3]	train-auc:0.98571+0.00378	test-auc:0.98093+0.00812
# [4]	train-auc:0.98731+0.00309	test-auc:0.98208+0.00819
# [5]	train-auc:0.98898+0.00188	test-auc:0.98381+0.00824
# [6]	train-auc:0.98920+0.00174	test-auc:0.98403+0.00778
# [7]	train-auc:0.99060+0.00104	test-auc:0.98538+0.00764
# [8]	train-auc:0.99148+0.00133	test-auc:0.98573+0.00660
# [9]	train-auc:0.99221+0.00110	test-auc:0.98662+0.00608
# [0]	train-auc:0.98142+0.00489	test-auc:0.96824+0.01424
# [1]	train-auc:0.99130+0.00263	test-auc:0.97898+0.01309
# [2]	train-auc:0.99465+0.00157	test-auc:0.98342+0.00868
# [3]	train-auc:0.99624+0.00110	test-auc:0.98676+0.00721
# [4]	train-auc:0.99710+0.00090	test-auc:0.98883+0.00693
# [5]	train-auc:0.99736+0.00074	test-auc:0.98987+0.00636
# [6]	train-auc:0.99776+0.00082	test-auc:0.99017+0.00534
# [7]	train-auc:0.99817+0.00059	test-auc:0.99014+0.00562
# [8]	train-auc:0.99839+0.00052	test-auc:0.99050+0.00522
# [9]	train-auc:0.99860+0.00043	test-auc:0.99041+0.00542
# [0]	train-auc:0.95292+0.00313	test-auc:0.94778+0.01533
# [1]	train-auc:0.96380+0.00827	test-auc:0.95767+0.01538
# [2]	train-auc:0.97415+0.00703	test-auc:0.96724+0.01416
# [3]	train-auc:0.97761+0.00564	test-auc:0.97235+0.01407
# [4]	train-auc:0.97939+0.00351	test-auc:0.97429+0.01501
# [5]	train-auc:0.98161+0.00297	test-auc:0.97515+0.01367
# [6]	train-auc:0.98318+0.00241	test-auc:0.97640+0.01213
# [7]	train-auc:0.98386+0.00332	test-auc:0.97714+0.01231
# [8]	train-auc:0.98503+0.00239	test-auc:0.97911+0.01089
# [9]	train-auc:0.98664+0.00175	test-auc:0.98086+0.00886
# [0]	train-auc:0.97215+0.00255	test-auc:0.96439+0.01641
# [1]	train-auc:0.98012+0.00496	test-auc:0.96996+0.01187
# [2]	train-auc:0.98638+0.00298	test-auc:0.97880+0.00851
# [3]	train-auc:0.98858+0.00230	test-auc:0.98134+0.00741
# [4]	train-auc:0.98983+0.00097	test-auc:0.98346+0.00779
# [5]	train-auc:0.99165+0.00131	test-auc:0.98509+0.00762
# [6]	train-auc:0.99201+0.00115	test-auc:0.98538+0.00742
# [7]	train-auc:0.99304+0.00119	test-auc:0.98699+0.00630
# [8]	train-auc:0.99378+0.00068	test-auc:0.98771+0.00668
# [9]	train-auc:0.99439+0.00099	test-auc:0.98829+0.00630
# [0]	train-auc:0.98435+0.00268	test-auc:0.97523+0.01423
# [1]	train-auc:0.99137+0.00193	test-auc:0.98293+0.00886
# [2]	train-auc:0.99480+0.00128	test-auc:0.98643+0.00736
# [3]	train-auc:0.99596+0.00127	test-auc:0.98736+0.00678
# [4]	train-auc:0.99691+0.00076	test-auc:0.98836+0.00566
# [5]	train-auc:0.99729+0.00081	test-auc:0.98983+0.00527
# [6]	train-auc:0.99770+0.00084	test-auc:0.99074+0.00557
# [7]	train-auc:0.99808+0.00054	test-auc:0.99192+0.00530
# [8]	train-auc:0.99838+0.00060	test-auc:0.99289+0.00458
# [9]	train-auc:0.99852+0.00053	test-auc:0.99361+0.00393
# [0]	train-auc:0.96524+0.00753	test-auc:0.96078+0.01529
# [1]	train-auc:0.97335+0.00460	test-auc:0.96807+0.01224
# [2]	train-auc:0.97829+0.00366	test-auc:0.97315+0.01371
# [3]	train-auc:0.98198+0.00435	test-auc:0.97683+0.01271
# [4]	train-auc:0.98468+0.00347	test-auc:0.98012+0.01253
# [5]	train-auc:0.98695+0.00263	test-auc:0.98275+0.01055
# [6]	train-auc:0.98792+0.00196	test-auc:0.98290+0.01073
# [7]	train-auc:0.98900+0.00208	test-auc:0.98455+0.00857
# [8]	train-auc:0.99006+0.00182	test-auc:0.98488+0.00874
# [9]	train-auc:0.99094+0.00158	test-auc:0.98532+0.00857
# [0]	train-auc:0.96561+0.00734	test-auc:0.96037+0.01342
# [1]	train-auc:0.97465+0.00361	test-auc:0.96787+0.01196
# [2]	train-auc:0.97930+0.00263	test-auc:0.97381+0.01453
# [3]	train-auc:0.98390+0.00343	test-auc:0.97823+0.01065
# [4]	train-auc:0.98531+0.00370	test-auc:0.97852+0.01097
# [5]	train-auc:0.98776+0.00359	test-auc:0.98087+0.01203
# [6]	train-auc:0.98879+0.00232	test-auc:0.98167+0.01174
# [7]	train-auc:0.99001+0.00166	test-auc:0.98393+0.01032
# [8]	train-auc:0.99080+0.00199	test-auc:0.98472+0.00959
# [9]	train-auc:0.99146+0.00163	test-auc:0.98604+0.00820
# [0]	train-auc:0.98432+0.00419	test-auc:0.97460+0.01290
# [1]	train-auc:0.98904+0.00441	test-auc:0.97891+0.01133
# [2]	train-auc:0.99228+0.00216	test-auc:0.98349+0.00937
# [3]	train-auc:0.99338+0.00233	test-auc:0.98527+0.00854
# [4]	train-auc:0.99402+0.00239	test-auc:0.98724+0.00754
# [5]	train-auc:0.99488+0.00138	test-auc:0.98802+0.00684
# [6]	train-auc:0.99535+0.00085	test-auc:0.98899+0.00638
# [7]	train-auc:0.99560+0.00081	test-auc:0.99049+0.00536
# [8]	train-auc:0.99569+0.00079	test-auc:0.99079+0.00499
# [9]	train-auc:0.99574+0.00077	test-auc:0.99106+0.00480
# [0]	train-auc:0.97893+0.00369	test-auc:0.97108+0.01474
# [1]	train-auc:0.98681+0.00308	test-auc:0.97747+0.01637
# [2]	train-auc:0.98979+0.00254	test-auc:0.98248+0.00917
# [3]	train-auc:0.99136+0.00217	test-auc:0.98414+0.00855
# [4]	train-auc:0.99259+0.00174	test-auc:0.98594+0.00851
# [5]	train-auc:0.99312+0.00173	test-auc:0.98662+0.00802
# [6]	train-auc:0.99329+0.00180	test-auc:0.98668+0.00781
# [7]	train-auc:0.99372+0.00170	test-auc:0.98667+0.00787
# [8]	train-auc:0.99406+0.00159	test-auc:0.98761+0.00653
# [9]	train-auc:0.99408+0.00164	test-auc:0.98775+0.00642
# [0]	validation_0-auc:0.98899	validation_1-auc:0.98179
# [1]	validation_0-auc:0.99568	validation_1-auc:0.98743
# [2]	validation_0-auc:0.99587	validation_1-auc:0.98773
# [3]	validation_0-auc:0.99630	validation_1-auc:0.98809
# [4]	validation_0-auc:0.99690	validation_1-auc:0.98813
# [5]	validation_0-auc:0.99713	validation_1-auc:0.98833
# [6]	validation_0-auc:0.99783	validation_1-auc:0.98804

# %%
viz.visualise_metrics(finalXGB)

# %%
viz.plotVariableImportance(finalXGB, viz_type=None)

# %%
viz.plotVariableImportance(finalXGB, viz_type='cover')

# %%
viz.make_shap_visualisation(finalXGB, xtrain)
