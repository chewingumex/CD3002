# %%
import pandas as pd
import xgboost
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
import shap
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# leer datos
df = pd.read_csv('./../datos/data_fraude.csv')

# %%
# pre-process datos (si es necesario)
df = df.rename(columns={'0.1':'Class'}).drop('Unnamed: 0',axis=1)

# %%
yvar = df.Class
xvars = df[[x for x in df.columns if x != 'Class']]

# %%
# dividir train / test para variables independientes (x)  y dependiente (y)
xtrain, xtest, ytrain, ytest = train_test_split(xvars, yvar, train_size = 0.80, random_state = 2)

# %%
# crear matrices de xgboost

trainXGB = xgboost.DMatrix(data=xtrain,
                           label=ytrain)

testXGB = xgboost.DMatrix(data=xtest,
                          label=ytest)

# %%
def findXGB(trainXGB,
           testXGB,
           iters):
    
    # iniciar el valor de la metrica del cual partimos (alto para metricas que queremos reducir
    # y viceversa
    
    best_metric = 0
    best_params = {}
    
    # muestrear numeros de forma aleatoria (dentro de un rango) para los hyperparámetros 
    # cada iteracion 
    
    for iteration in range(iters):

        params = {
                'tree_method' : 'exact',
                'booster' : 'gbtree', # 'gblinear'
                'eta' : random.uniform(0.01, 0.3),
                'max_depth' : random.randint(5,14),
                'reg_lambda' : random.uniform(0.01, 0.4),
                'reg_alpha' : random.uniform(0.01, 0.4),
                'gamma' : random.randint(0, 20),
                'subsample' : random.uniform(0.5, 1),
                'colsample_bytree' : random.uniform(0.5, 1),
                'objective' : 'binary:logistic',
                'eval_metric' : 'auc'
            }
    
    # ajustar un modelo utilizando validacion cruzada para probar los hiperparámetros en
    # todas las regiones de los datos de entrenamiento
    
        xgb_cv = xgboost.cv(
            params = params, 
            dtrain = trainXGB, 
               nfold=10,
               metrics={'auc'}, 
               seed=2345,
               callbacks=[xgboost.callback.EvaluationMonitor(show_stdv=True),
                          xgboost.callback.EarlyStopping(2)]
        )
 
    # registrar la metrica
    
        auc = xgb_cv.iloc[-1,2]
    
    # si la metrica alcanzada fuera mejor que la actual, reemplazar la actual  y guardar los
    # hiperparámetros del modelo que llegó a ella.
    # Nota : la metrica debe ser menor si se esta reduciendo (ej rmse) o mayor si se esta aumentando (ej auc)
    
        if auc > best_metric:

            best_metric = auc
            best_params = params
    
    # Ajustar un modelo final con los mejores hiperparámetros, probándolo ahora en el test set
    
    final_model = xgboost.XGBClassifier( 
        eval_metric='auc',
        early_stopping_rounds=2,
        n_estimators=1000000
    )

    final_model.set_params(**best_params)

    final_model.fit(
        X=xtrain,
        y=ytrain,
        eval_set = [(xtrain, ytrain),(xtest, ytest)]
    )
    
    return final_model

# %%
# correr la función
finalXGB = findXGB(trainXGB, testXGB, iters=10)
# Out:
# [0]	train-auc:0.96780+0.00568	test-auc:0.96032+0.01635
# [1]	train-auc:0.97867+0.00633	test-auc:0.97032+0.01098
# [2]	train-auc:0.98722+0.00230	test-auc:0.97932+0.00842
# [3]	train-auc:0.98825+0.00150	test-auc:0.98003+0.00870
# [4]	train-auc:0.98903+0.00099	test-auc:0.98278+0.00823
# [5]	train-auc:0.99013+0.00145	test-auc:0.98399+0.00723
# [6]	train-auc:0.99067+0.00104	test-auc:0.98490+0.00708
# [7]	train-auc:0.99211+0.00119	test-auc:0.98562+0.00579
# [8]	train-auc:0.99292+0.00101	test-auc:0.98747+0.00482
# [9]	train-auc:0.99396+0.00058	test-auc:0.98829+0.00486
# [0]	train-auc:0.98051+0.00484	test-auc:0.97099+0.01440
# [1]	train-auc:0.98853+0.00177	test-auc:0.98052+0.01001
# [2]	train-auc:0.99137+0.00106	test-auc:0.98290+0.01011
# [3]	train-auc:0.99232+0.00127	test-auc:0.98509+0.00804
# [4]	train-auc:0.99287+0.00114	test-auc:0.98666+0.00691
# [5]	train-auc:0.99342+0.00081	test-auc:0.98719+0.00702
# [6]	train-auc:0.99378+0.00071	test-auc:0.98768+0.00632
# [7]	train-auc:0.99390+0.00063	test-auc:0.98776+0.00607
# [8]	train-auc:0.99405+0.00057	test-auc:0.98791+0.00617
# [9]	train-auc:0.99442+0.00065	test-auc:0.98804+0.00626
# [0]	train-auc:0.96903+0.00420	test-auc:0.96429+0.01548
# [1]	train-auc:0.97671+0.00346	test-auc:0.97302+0.01329
# [2]	train-auc:0.98277+0.00389	test-auc:0.97603+0.01462
# [3]	train-auc:0.98540+0.00243	test-auc:0.97922+0.01054
# [4]	train-auc:0.98808+0.00215	test-auc:0.98235+0.01010
# [5]	train-auc:0.98929+0.00186	test-auc:0.98486+0.00869
# [6]	train-auc:0.99000+0.00163	test-auc:0.98516+0.00947
# [7]	train-auc:0.99071+0.00158	test-auc:0.98599+0.00791
# [8]	train-auc:0.99125+0.00181	test-auc:0.98649+0.00788
# [9]	train-auc:0.99192+0.00127	test-auc:0.98850+0.00591
# [0]	train-auc:0.98398+0.00264	test-auc:0.97230+0.01162
# [1]	train-auc:0.98932+0.00177	test-auc:0.97827+0.00981
# [2]	train-auc:0.99186+0.00164	test-auc:0.98149+0.00988
# [3]	train-auc:0.99246+0.00163	test-auc:0.98299+0.00915
# [4]	train-auc:0.99315+0.00189	test-auc:0.98554+0.00842
# [5]	train-auc:0.99418+0.00168	test-auc:0.98670+0.00829
# [6]	train-auc:0.99435+0.00164	test-auc:0.98713+0.00806
# [7]	train-auc:0.99460+0.00167	test-auc:0.98800+0.00756
# [8]	train-auc:0.99476+0.00142	test-auc:0.98904+0.00660
# [9]	train-auc:0.99480+0.00143	test-auc:0.98902+0.00675
# [0]	train-auc:0.97466+0.00339	test-auc:0.97096+0.01408
# [1]	train-auc:0.98465+0.00166	test-auc:0.97853+0.01223
# [2]	train-auc:0.98827+0.00178	test-auc:0.98175+0.01151
# [3]	train-auc:0.99081+0.00103	test-auc:0.98558+0.00832
# [4]	train-auc:0.99215+0.00127	test-auc:0.98636+0.00800
# [5]	train-auc:0.99311+0.00090	test-auc:0.98718+0.00728
# [6]	train-auc:0.99380+0.00078	test-auc:0.98871+0.00646
# [7]	train-auc:0.99412+0.00073	test-auc:0.98956+0.00578
# [8]	train-auc:0.99461+0.00082	test-auc:0.99067+0.00489
# [9]	train-auc:0.99533+0.00056	test-auc:0.99122+0.00419
# [0]	train-auc:0.97748+0.00271	test-auc:0.96744+0.01284
# [1]	train-auc:0.98476+0.00239	test-auc:0.97378+0.01093
# [2]	train-auc:0.98814+0.00184	test-auc:0.97831+0.00868
# [3]	train-auc:0.98894+0.00161	test-auc:0.98037+0.00752
# [4]	train-auc:0.98985+0.00144	test-auc:0.98284+0.00781
# [5]	train-auc:0.99067+0.00090	test-auc:0.98487+0.00783
# [6]	train-auc:0.99116+0.00053	test-auc:0.98596+0.00738
# [7]	train-auc:0.99138+0.00069	test-auc:0.98612+0.00745
# [8]	train-auc:0.99168+0.00067	test-auc:0.98627+0.00747
# [9]	train-auc:0.99215+0.00089	test-auc:0.98684+0.00701
# [0]	train-auc:0.97870+0.00469	test-auc:0.96811+0.01660
# [1]	train-auc:0.98713+0.00151	test-auc:0.97579+0.01501
# [2]	train-auc:0.99115+0.00176	test-auc:0.98093+0.01048
# [3]	train-auc:0.99230+0.00160	test-auc:0.98328+0.00859
# [4]	train-auc:0.99278+0.00152	test-auc:0.98534+0.00798
# [5]	train-auc:0.99306+0.00155	test-auc:0.98555+0.00818
# [6]	train-auc:0.99339+0.00157	test-auc:0.98585+0.00808
# [7]	train-auc:0.99397+0.00142	test-auc:0.98661+0.00724
# [8]	train-auc:0.99486+0.00100	test-auc:0.98803+0.00564
# [9]	train-auc:0.99525+0.00070	test-auc:0.98823+0.00598
# [0]	train-auc:0.97737+0.00314	test-auc:0.96901+0.01452
# [1]	train-auc:0.98781+0.00227	test-auc:0.97994+0.01020
# [2]	train-auc:0.99230+0.00163	test-auc:0.98507+0.00823
# [3]	train-auc:0.99393+0.00115	test-auc:0.98836+0.00606
# [4]	train-auc:0.99480+0.00117	test-auc:0.98874+0.00582
# [5]	train-auc:0.99531+0.00115	test-auc:0.98948+0.00551
# [6]	train-auc:0.99588+0.00112	test-auc:0.99000+0.00517
# [7]	train-auc:0.99639+0.00087	test-auc:0.99117+0.00564
# [8]	train-auc:0.99654+0.00094	test-auc:0.99188+0.00543
# [9]	train-auc:0.99683+0.00067	test-auc:0.99218+0.00458
# [0]	train-auc:0.98091+0.00280	test-auc:0.97297+0.00976
# [1]	train-auc:0.98981+0.00113	test-auc:0.98140+0.00882
# [2]	train-auc:0.99272+0.00139	test-auc:0.98441+0.00950
# [3]	train-auc:0.99470+0.00094	test-auc:0.98556+0.00917
# [4]	train-auc:0.99553+0.00100	test-auc:0.98694+0.00807
# [5]	train-auc:0.99645+0.00075	test-auc:0.98847+0.00710
# [6]	train-auc:0.99672+0.00087	test-auc:0.98889+0.00663
# [7]	train-auc:0.99714+0.00081	test-auc:0.98885+0.00702
# [8]	train-auc:0.99740+0.00067	test-auc:0.98992+0.00654
# [9]	train-auc:0.99770+0.00041	test-auc:0.99142+0.00568
# [0]	train-auc:0.97908+0.00552	test-auc:0.96869+0.00782
# [1]	train-auc:0.98957+0.00194	test-auc:0.97943+0.00752
# [2]	train-auc:0.99305+0.00171	test-auc:0.98360+0.00819
# [3]	train-auc:0.99520+0.00119	test-auc:0.98715+0.00679
# [4]	train-auc:0.99612+0.00079	test-auc:0.98840+0.00614
# [5]	train-auc:0.99698+0.00057	test-auc:0.98976+0.00641
# [6]	train-auc:0.99750+0.00045	test-auc:0.99083+0.00519
# [7]	train-auc:0.99809+0.00049	test-auc:0.99155+0.00474
# [8]	train-auc:0.99859+0.00041	test-auc:0.99305+0.00384
# [9]	train-auc:0.99876+0.00039	test-auc:0.99350+0.00382
# [0]	validation_0-auc:0.98739	validation_1-auc:0.98055
# [1]	validation_0-auc:0.99177	validation_1-auc:0.98017
# [2]	validation_0-auc:0.99376	validation_1-auc:0.98694
# [3]	validation_0-auc:0.99465	validation_1-auc:0.98736
# [4]	validation_0-auc:0.99458	validation_1-auc:0.98804
# [5]	validation_0-auc:0.99554	validation_1-auc:0.98759
# [6]	validation_0-auc:0.99699	validation_1-auc:0.98939
# [7]	validation_0-auc:0.99731	validation_1-auc:0.99001
# [8]	validation_0-auc:0.99726	validation_1-auc:0.99014
# [9]	validation_0-auc:0.99884	validation_1-auc:0.99301
# [10]	validation_0-auc:0.99908	validation_1-auc:0.99328
# [11]	validation_0-auc:0.99922	validation_1-auc:0.99462
# [12]	validation_0-auc:0.99932	validation_1-auc:0.99502
# [13]	validation_0-auc:0.99948	validation_1-auc:0.99613
# [14]	validation_0-auc:0.99948	validation_1-auc:0.99577

# %%
# visualize metrics 

results = finalXGB.evals_result_
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(range(len(results['validation_0']['auc'])), results['validation_0']['auc'], label='train auc')
ax.plot(range(len(results['validation_1']['auc'])), results['validation_1']['auc'], label='test auc')
ax.legend()
plt.ylabel("auc")
plt.title('AUC at Training')
plt.show()

# %%
xgboost.plot_importance(finalXGB)
plt.title("xgboost.plot_importance(model)")
plt.show()

# %%
xgboost.plot_importance(finalXGB, importance_type="cover")
plt.title('xgboost.plot_importance(model, importance_type="cover")')
plt.show()

# %%
xgboost.plot_importance(finalXGB, importance_type="gain")
plt.title('xgboost.plot_importance(model, importance_type="gain")')
plt.show()

# %%
# SHAP
explainer = shap.TreeExplainer(finalXGB)
shap_values = explainer.shap_values(xtrain)

# %%
shap.summary_plot(shap_values, xtrain)
